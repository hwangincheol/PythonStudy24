# %% [markdown]
# <a href="https://colab.research.google.com/github/hwangincheol/PythonStudy24/blob/master/WhileStudy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# while문
#
# while문은 문장을 반복해서 수행해야 되는 경우 활용 (반복문)
#
# 반복문은 여러 데이터를 처리해야 하는 경우 사용함
#
# if문에서 성적처리를 할 때 1명에 데이터를 처리하지만 입력을 여러명 받아 더 큰 프로그램을 만들 수 있다.
#
# 반복문은 while문과 for문으로 활용되는데 while문은 max가 없는 반복문일 경우 사용되고 for문은 max가 있는 경우 사용 됨
#
# while 조건문 :
#     실행문1
#     실행문2
#     실행문3
#
# java에서는 {} 으로 실행문의 블럭을 만들지만 파이썬은 들여쓰기로 판단함.

# %%
# 열번찍어 안넘어가는 나무 없다.
treeHit = 0
while treeHit < 10: # 조건 : treeHit가 10보다 작으면
    treeHit = treeHit + 1   # 반복중에 1씩 증가
    print("나무를 %d번 찍었습니다." % treeHit)
    if treeHit == 10:   # 도끼로 찍은 나무의 타격 횟수 10번인지 판단
        print("나무 넘어갑니다.")
    else:
        print("나무가 아직 넘어가지 않았습니다.")
# Out:
# 나무를 1번 찍었습니다.
# 나무가 아직 넘어가지 않았습니다.
# 나무를 2번 찍었습니다.
# 나무가 아직 넘어가지 않았습니다.
# 나무를 3번 찍었습니다.
# 나무가 아직 넘어가지 않았습니다.
# 나무를 4번 찍었습니다.
# 나무가 아직 넘어가지 않았습니다.
# 나무를 5번 찍었습니다.
# 나무가 아직 넘어가지 않았습니다.
# 나무를 6번 찍었습니다.
# 나무가 아직 넘어가지 않았습니다.
# 나무를 7번 찍었습니다.
# 나무가 아직 넘어가지 않았습니다.
# 나무를 8번 찍었습니다.
# 나무가 아직 넘어가지 않았습니다.
# 나무를 9번 찍었습니다.
# 나무가 아직 넘어가지 않았습니다.
# 나무를 10번 찍었습니다.
# 나무 넘어갑니다.

# %%
#콘솔에서 프로그램 만들어 보기

prompt = """
========================
1. 학생가입
2. 성적입력
3. 성적출력
4. Quit

Enter number :
"""
number = 0                  # 키보드로 전달되는 변수 초기값
while number != 4:          # 4가 아닐때까지 반복문 -> 4입력시 while문 종료
    print(prompt)           # 4가 아닐때 prompt 출력
    number = int(input())   # 반복중에 입력받을 프롬프트

print("종료합니다.")
# Out:
# ========================
# 1. 학생가입
# 2. 성적입력
# 3. 성적출력
# 4. Quit
#
# Enter number :
#
# 1
#
# ========================
# 1. 학생가입
# 2. 성적입력
# 3. 성적출력
# 4. Quit
#
# Enter number :
#
# 4
# 종료합니다.

# %%
# 커피 자판기 프로그램
coffee = 10  # 커피는 총 10잔이 준비 되어 있음
money = 300 # 현재 입금된 금액은 300원
while money:
    print("돈을 받았으니 커피를 줍니다.")
    coffee = coffee -1   # 1잔씩 소모
    print("남은 커피의 양은 %d개입니다." % coffee)
    if coffee == 0:
        print("커피가 다 떨어졌습니다. 판매를 중지합니다.")
        break
# Out:
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 9개입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 8개입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 7개입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 6개입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 5개입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 4개입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 3개입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 2개입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 1개입니다.
# 돈을 받았으니 커피를 줍니다.
# 남은 커피의 양은 0개입니다.
# 커피가 다 떨어졌습니다. 판매를 중지합니다.

# %%
# 미션
# 관리자가 커피 가겨고가 커피명을 정하고 개수를 입력한다.
# 소비자가 커피를 구매하는데 잔돈이 나와야 함
# 판매 종료 후 관리자가 커피 판매한 총액을 파악해야 함
# (if와 while 두개 사용하기)

prompt1 = """
- 금액 투입 단계-
=======================================
| 1. 음료1 300원   | 2. 음료2 400원   |
=======================================
| 3. 음료3 500원   | 4. 음료4 600원   |
=======================================

구매하기전 원하는 만큼 금액을 투입하고
         '구매'를 입력해주세요.
=======================================
"""

prompt2 = """
- 음료 구매 단계 -
=======================================
| 1. 음료1 300원   | 2. 음료2 400원   |
=======================================
| 3. 음료3 500원   | 4. 음료4 600원   |
=======================================

      구매가 끝나셨으면 거스름 돈
         '반환'을 입력해주세요.
=======================================
"""

drink = [10, 10, 10, 10]    # 음료 1,2,3,4 기본수량
totalMoney = 0  # 넣은 금액
sumPrice = 0    # 판매 총액

while True:
    print("\n\n")
    print(prompt1)
    print(" >>>    현재 잔액 : %d원" % totalMoney)
    money = input("\n 얼마를 넣을까요? : ")

    if money == "종료":
        print("\n\n\n 프로그램을 종료합니다.")
        break
    elif money == "관리자":
        while True:
            print("\n\n\n===============================================================")
            print("        관리자 모드를 실행합니다 ")
            print("       >>> 판매 총액 : %d원<<<" % sumPrice)
            print("===============================================================")
            print(" 1. 음료1(%d개), 2. 음료2(%d개), 3. 음료3(%d개), 4. 음료4(%d개)" % (drink[0],drink[1],drink[2],drink[3]))
            print("===============================================================")
            input2 = input("\n판매 모드로 돌아가려면 '판매'를 입력해주세요 : ")
            if input2 == '판매': break
    elif money == "구매":
        while True:
            print("\n\n")
            print(prompt2)
            print(" >>>    현재 잔액 : %d원" % totalMoney)
            input1 = input("\n 구매하고 싶은 음료의 번호를 입력해주세요 : ")
            print("\n\n\n >>> ")
            if input1 == "반환":
                print(" 거스름돈 %d원을 반환합니다." % totalMoney)
                print(" 이용 해주셔서 감사합니다 ^^")
                totalMoney = 0
                break
            elif input1 == '1':
                if totalMoney >= 300:
                    if drink[0] > 0:
                        drink[0] = drink[0] - 1
                        totalMoney = totalMoney - 300
                        sumPrice = sumPrice + 300
                        print(">>> 음료1을 구매합니다.")
                    else: print(">>> 음료1은 현재 품절입니다.")
                else: print(">>> 금액이 부족합니다.")
            elif input1 == '2':
                if totalMoney >= 400:
                    if drink[1] > 0:
                        drink[1] = drink[1] - 1
                        totalMoney = totalMoney - 400
                        sumPrice = sumPrice + 400
                        print(">>> 음료2을 구매합니다.")
                    else: print(">>> 음료2은 현재 품절입니다.")
                else: print(">>> 금액이 부족합니다.")
            elif input1 == '3':
                if totalMoney >= 500:
                    if drink[2] > 0:
                        drink[2] = drink[2] - 1
                        totalMoney = totalMoney - 500
                        sumPrice = sumPrice + 500
                        print(">>> 음료3을 구매합니다.")
                    else: print(">>> 음료3은 현재 품절입니다.")
                else: print(">>> 금액이 부족합니다.")
            elif input1 == '4':
                if totalMoney >= 600:
                    if drink[3] > 0:
                        drink[3] = drink[3] - 1
                        totalMoney = totalMoney - 600
                        sumPrice = sumPrice + 600
                        print(">>> 음료4을 구매합니다.")
                    else: print(">>> 음료4은 현재 품절입니다.")
                else: print(">>> 금액이 부족합니다.")
            else: print("\n\n\n!!!!!! 잘못 입력하셨습니다. !!!!!!")
    elif not money.isdigit(): print("\n\n\n!!!!!! 잘못 입력하셨습니다. !!!!!!")
    else : totalMoney = totalMoney + int(money)
# Out:
# - 금액 투입 단계-
# =======================================
# | 1. 음료1 300원   | 2. 음료2 400원   |
# =======================================
# | 3. 음료3 500원   | 4. 음료4 600원   |
# =======================================
#
# 구매하기전 원하는 만큼 금액을 투입하고
#          '구매'를 입력해주세요.
# =======================================
#
#  >>>    현재 잔액 : 0원
#
#  얼마를 넣을까요? : 2000\
#
#
#
# !!!!!! 잘못 입력하셨습니다. !!!!!!
#
#
#
#
# - 금액 투입 단계-
# =======================================
# | 1. 음료1 300원   | 2. 음료2 400원   |
# =======================================
# | 3. 음료3 500원   | 4. 음료4 600원   |
# =======================================
#
# 구매하기전 원하는 만큼 금액을 투입하고
#          '구매'를 입력해주세요.
# =======================================
#
#  >>>    현재 잔액 : 0원
#
#  얼마를 넣을까요? : 2000
#
#
#
#
# - 금액 투입 단계-
# =======================================
# | 1. 음료1 300원   | 2. 음료2 400원   |
# =======================================
# | 3. 음료3 500원   | 4. 음료4 600원   |
# =======================================
#
# 구매하기전 원하는 만큼 금액을 투입하고
#          '구매'를 입력해주세요.
# =======================================
#
#  >>>    현재 잔액 : 2000원
#
#  얼마를 넣을까요? : 1
#
#
#
#
# - 금액 투입 단계-
# =======================================
# | 1. 음료1 300원   | 2. 음료2 400원   |
# =======================================
# | 3. 음료3 500원   | 4. 음료4 600원   |
# =======================================
#
# 구매하기전 원하는 만큼 금액을 투입하고
#          '구매'를 입력해주세요.
# =======================================
#
#  >>>    현재 잔액 : 2001원
#
#  얼마를 넣을까요? : 구매
#
#
#
#
# - 음료 구매 단계 -
# =======================================
# | 1. 음료1 300원   | 2. 음료2 400원   |
# =======================================
# | 3. 음료3 500원   | 4. 음료4 600원   |
# =======================================
#
#       구매가 끝나셨으면 거스름 돈
#          '반환'을 입력해주세요.
# =======================================
#
#  >>>    현재 잔액 : 2001원
#
#  구매하고 싶은 음료의 번호를 입력해주세요 : 1
#
#
#
#  >>>
# >>> 음료1을 구매합니다.
#
#
#
#
# - 음료 구매 단계 -
# =======================================
# | 1. 음료1 300원   | 2. 음료2 400원   |
# =======================================
# | 3. 음료3 500원   | 4. 음료4 600원   |
# =======================================
#
#       구매가 끝나셨으면 거스름 돈
#          '반환'을 입력해주세요.
# =======================================
#
#  >>>    현재 잔액 : 1701원
#
#  구매하고 싶은 음료의 번호를 입력해주세요 : 2
#
#
#
#  >>>
# >>> 음료2을 구매합니다.
#
#
#
#
# - 음료 구매 단계 -
# =======================================
# | 1. 음료1 300원   | 2. 음료2 400원   |
# =======================================
# | 3. 음료3 500원   | 4. 음료4 600원   |
# =======================================
#
#       구매가 끝나셨으면 거스름 돈
#          '반환'을 입력해주세요.
# =======================================
#
#  >>>    현재 잔액 : 1301원
#
#  구매하고 싶은 음료의 번호를 입력해주세요 : 3
#
#
#
#  >>>
# >>> 음료3을 구매합니다.
#
#
#
#
# - 음료 구매 단계 -
# =======================================
# | 1. 음료1 300원   | 2. 음료2 400원   |
# =======================================
# | 3. 음료3 500원   | 4. 음료4 600원   |
# =======================================
#
#       구매가 끝나셨으면 거스름 돈
#          '반환'을 입력해주세요.
# =======================================
#
#  >>>    현재 잔액 : 801원
#
#  구매하고 싶은 음료의 번호를 입력해주세요 : 1
#
#
#
#  >>>
# >>> 음료1을 구매합니다.
#
#
#
#
# - 음료 구매 단계 -
# =======================================
# | 1. 음료1 300원   | 2. 음료2 400원   |
# =======================================
# | 3. 음료3 500원   | 4. 음료4 600원   |
# =======================================
#
#       구매가 끝나셨으면 거스름 돈
#          '반환'을 입력해주세요.
# =======================================
#
#  >>>    현재 잔액 : 501원
#
#  구매하고 싶은 음료의 번호를 입력해주세요 : 4
#
#
#
#  >>>
# >>> 금액이 부족합니다.
#
#
#
#
# - 음료 구매 단계 -
# =======================================
# | 1. 음료1 300원   | 2. 음료2 400원   |
# =======================================
# | 3. 음료3 500원   | 4. 음료4 600원   |
# =======================================
#
#       구매가 끝나셨으면 거스름 돈
#          '반환'을 입력해주세요.
# =======================================
#
#  >>>    현재 잔액 : 501원
#
#  구매하고 싶은 음료의 번호를 입력해주세요 : 반환
#
#
#
#  >>>
#  거스름돈 501원을 반환합니다.
#  이용 해주셔서 감사합니다 ^^
#
#
#
#
# - 금액 투입 단계-
# =======================================
# | 1. 음료1 300원   | 2. 음료2 400원   |
# =======================================
# | 3. 음료3 500원   | 4. 음료4 600원   |
# =======================================
#
# 구매하기전 원하는 만큼 금액을 투입하고
#          '구매'를 입력해주세요.
# =======================================
#
#  >>>    현재 잔액 : 0원
#
#  얼마를 넣을까요? : 관리자
#
#
#
# ===============================================================
#         관리자 모드를 실행합니다
#        >>> 판매 총액 : 1500원<<<
# ===============================================================
#  1. 음료1(8개), 2. 음료2(9개), 3. 음료3(9개), 4. 음료4(10개)
# ===============================================================
#
# 판매 모드로 돌아가려면 '판매'를 입력해주세요 : 판매
#
#
#
#
# - 금액 투입 단계-
# =======================================
# | 1. 음료1 300원   | 2. 음료2 400원   |
# =======================================
# | 3. 음료3 500원   | 4. 음료4 600원   |
# =======================================
#
# 구매하기전 원하는 만큼 금액을 투입하고
#          '구매'를 입력해주세요.
# =======================================
#
#  >>>    현재 잔액 : 0원
#
#  얼마를 넣을까요? : 종료
#
#
#
#  프로그램을 종료합니다.
